# %% [markdown]
# <a href="https://colab.research.google.com/github/LeTienNhan20104048/LeTienNhan20104048/blob/main/Tuan_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
with open('text.txt', mode='w') as accounts:
  accounts.write('1 Nguyen Van A 8.0\n')
  accounts.write('2 Le Thi B 6.8\n')

# %%
with open('text1.txt', mode='w') as accounts:
  print('7:00 Nguyen Van A', file= accounts)
  print('7:01 Le Thi B', file= accounts)

# %%
with open ('text.txt', mode = 'r') as accounts:
  print(f'{"number":<10}{"name":<10}{"score":>10}')
  for record in accounts:
    number, name, score = record.split()
    print(f'{name:<10}{score:>10}')

# %%
import pandas as pd
url='/csv.csv'
dataframe = pd.read_csv(url)
dataframe.head(10)
# Out:
#    STT      MSSV      Ho va ten  Diem Khoa
# 0    1  20104001   Nguyen Van F     5  CKM
# 1    2  20104002       Le Thi B     4  FHQ
# 2    3  20104003     Tran Van C     3  FHQ
# 3    4  20104004    Huynh Thi D     5  FHQ
# 4    5  20104005   Truong Tan E     7  FHQ
# 5    6  20104006       Le Tan H     8  CKM
# 6    7  20104007    Nguyen Le G     6  CKM
# 7    8  20104008     Tran Thi K     2  FHQ
# 8    9  20104009  Nguyen Hong K     4  CKM
# 9   10  20104010     Pham Thi S    10  FHQ

# %%
import pandas as pd
dataframe=pd.DataFrame ()
dataframe['Name']=['Nguyen Van A','Le Thi B']
dataframe['Student.ID']=[20104011,20104067]
dataframe['score']=[8.0,9.0]
dataframe
# Out:
#            Name  Student.ID  score
# 0  Nguyen Van A    20104011    8.0
# 1      Le Thi B    20104067    9.0

# %%
import pandas as pd
url='/csv.csv'
dataframe= pd.read_csv(url)
dataframe[:4]
# Out:
#    STT      MSSV     Ho va ten  Diem Khoa
# 0    1  20104001  Nguyen Van F     5  CKM
# 1    2  20104002      Le Thi B     4  FHQ
# 2    3  20104003    Tran Van C     3  FHQ
# 3    4  20104004   Huynh Thi D     5  FHQ

# %%
import pandas as pd
url='/csv.csv'
dataframe= pd.read_csv(url)
dataframe=dataframe.set_index(dataframe['Ho va ten'])
dataframe.loc['Nguyen Van F']
# Out:
# STT                     1
# MSSV             20104001
# Ho va ten    Nguyen Van F
# Diem                    5
# Khoa                  CKM
# Name: Nguyen Van F, dtype: object

# %%
import pandas as pd
url='/csv.csv'
dataframe= pd.read_csv(url)
dataframe[(dataframe['Khoa'] =='CKM')].head(4)
# Out:
#    STT      MSSV      Ho va ten  Diem Khoa
# 0    1  20104001   Nguyen Van F     5  CKM
# 5    6  20104006       Le Tan H     8  CKM
# 6    7  20104007    Nguyen Le G     6  CKM
# 8    9  20104009  Nguyen Hong K     4  CKM

# %%
import pandas as pd
url='/csv.csv'
dataframe= pd.read_csv(url)
dataframe[(dataframe['Khoa']=='FHQ') & (dataframe['Diem']>=2)]
# Out:
#    STT      MSSV     Ho va ten  Diem Khoa
# 1    2  20104002      Le Thi B     4  FHQ
# 2    3  20104003    Tran Van C     3  FHQ
# 3    4  20104004   Huynh Thi D     5  FHQ
# 4    5  20104005  Truong Tan E     7  FHQ
# 7    8  20104008    Tran Thi K     2  FHQ
# 9   10  20104010    Pham Thi S    10  FHQ

# %%
import pandas as pd
url='/csv.csv'
dataframe= pd.read_csv(url)
dataframe['Khoa'].unique()
# Out:
# array(['CKM', 'FHQ'], dtype=object)

# %%
import pandas as pd
url='/csv.csv'
dataframe= pd.read_csv(url)
dataframe['Khoa'].value_counts()
# Out:
# FHQ    6
# CKM    4
# Name: Khoa, dtype: int64

# %%
value.counts

# %%
import pandas as pd
url='/csv.csv'
dataframe= pd.read_csv(url)
dataframe.drop('Khoa', axis=1).head(10)
# Out:
#    STT      MSSV      Ho va ten  Diem
# 0    1  20104001   Nguyen Van F     5
# 1    2  20104002       Le Thi B     4
# 2    3  20104003     Tran Van C     3
# 3    4  20104004    Huynh Thi D     5
# 4    5  20104005   Truong Tan E     7
# 5    6  20104006       Le Tan H     8
# 6    7  20104007    Nguyen Le G     6
# 7    8  20104008     Tran Thi K     2
# 8    9  20104009  Nguyen Hong K     4
# 9   10  20104010     Pham Thi S    10

# %%
import pandas as pd
url='/csv.csv'
dataframe= pd.read_csv(url)
dataframe.groupby('Khoa').mean()
# Out:
#            STT          MSSV      Diem
# Khoa
# CKM   5.750000  2.010401e+07  5.750000
# FHQ   5.333333  2.010401e+07  5.166667

# %%
import pandas as pd
url='/csv.csv'
dataframe= pd.read_csv(url)
dataframe.groupby('Khoa').count()
# Out:
#       STT  MSSV  Ho va ten  Diem
# Khoa
# CKM     4     4          4     4
# FHQ     6     6          6     6

# %%
import pandas as pd
url = 'http://winterolympicsmedals.com/medals.csv'
data = pd.read_csv(url)
data
# Out:
#       Year      City       Sport      Discipline  NOC            Event  \
# 0     1924  Chamonix     Skating  Figure skating  AUT       individual
# 1     1924  Chamonix     Skating  Figure skating  AUT       individual
# 2     1924  Chamonix     Skating  Figure skating  AUT            pairs
# 3     1924  Chamonix   Bobsleigh       Bobsleigh  BEL         four-man
# 4     1924  Chamonix  Ice Hockey      Ice Hockey  CAN       ice hockey
# ...    ...       ...         ...             ...  ...              ...
# 2306  2006     Turin      Skiing       Snowboard  USA        Half-pipe
# 2307  2006     Turin      Skiing       Snowboard  USA        Half-pipe
# 2308  2006     Turin      Skiing       Snowboard  USA        Half-pipe
# 2309  2006     Turin      Skiing       Snowboard  USA  Snowboard Cross
# 2310  2006     Turin      Skiing       Snowboard  USA  Snowboard Cross
#
#      Event gender   Medal
# 0               M  Silver
# 1               W    Gold
# 2               X    Gold
# ...

# %%
import pandas as pd
url = 'http://winterolympicsmedals.com/medals.csv'
data = pd.read_csv(url)
data['NOC'].unique()
# Out:
# array(['AUT', 'BEL', 'CAN', 'FIN', 'FRA', 'GBR', 'NOR', 'SUI', 'SWE',
#        'USA', 'GER', 'TCH', 'HUN', 'ITA', 'FRG', 'NED', 'EUA', 'JPN',
#        'POL', 'URS', 'PRK', 'GDR', 'ROU', 'ESP', 'LIE', 'BUL', 'YUG',
#        'CHN', 'EUN', 'KOR', 'LUX', 'NZL', 'AUS', 'BLR', 'KAZ', 'RUS',
#        'SLO', 'UKR', 'UZB', 'CZE', 'DEN', 'CRO', 'EST', 'LAT', 'SVK'],
#       dtype=object)

# %%
import pandas as pd
url = 'http://winterolympicsmedals.com/medals.csv'
data = pd.read_csv(url)
data = data.set_index(data['Medal'])
data.loc['Gold']
# Out:
#        Year      City       Sport      Discipline  NOC            Event  \
# Medal
# Gold   1924  Chamonix     Skating  Figure skating  AUT       individual
# Gold   1924  Chamonix     Skating  Figure skating  AUT            pairs
# Gold   1924  Chamonix  Ice Hockey      Ice Hockey  CAN       ice hockey
# Gold   1924  Chamonix     Skating   Speed skating  FIN           10000m
# Gold   1924  Chamonix     Skating   Speed skating  FIN            1500m
# ...     ...       ...         ...             ...  ...              ...
# Gold   2006     Turin      Skiing   Alpine Skiing  USA  Alpine combined
# Gold   2006     Turin      Skiing   Alpine Skiing  USA     giant slalom
# Gold   2006     Turin      Skiing       Snowboard  USA        Half-pipe
# Gold   2006     Turin      Skiing       Snowboard  USA        Half-pipe
# Gold   2006     Turin      Skiing       Snowboard  USA  Snowboard Cross
#
#       Event gender Medal
# Medal
# Gold             W  Gold
# Gold             X  Gold
# ...

# %%
import pandas as pd
url = 'http://winterolympicsmedals.com/medals.csv'
data = pd.read_csv(url)
data[(data['Medal']=='Gold') & (data['Event gender']=='W') & (data['NOC']=='CAN')]
# Out:
#       Year            City       Sport       Discipline  NOC         Event  \
# 194   1948      St. Moritz     Skating   Figure skating  CAN    individual
# 399   1960    Squaw Valley      Skiing    Alpine Skiing  CAN        slalom
# 586   1968        Grenoble      Skiing    Alpine Skiing  CAN  giant slalom
# 793   1976       Innsbruck      Skiing    Alpine Skiing  CAN  giant slalom
# 1291  1992     Albertville     Skating   Short Track S.  CAN   3000m relay
# 1293  1992     Albertville      Skiing    Alpine Skiing  CAN      downhill
# 1449  1994     Lillehammer    Biathlon         Biathlon  CAN          15km
# 1450  1994     Lillehammer    Biathlon         Biathlon  CAN         7.5km
# 1644  1998          Nagano     Curling          Curling  CAN       curling
# 1650  1998          Nagano     Skating   Short Track S.  CAN          500m
# 1654  1998          Nagano     Skating    Speed skating  CAN          500m
# ...

# %%
import pandas as pd
url = 'http://winterolympicsmedals.com/medals.csv'
data = pd.read_csv(url)
data.groupby('Year').count()
# Out:
#       City  Sport  Discipline  NOC  Event  Event gender  Medal
# Year
# 1924    49     49          49   49     49            49     49
# 1928    41     41          41   41     41            41     41
# 1932    42     42          42   42     42            42     42
# 1936    51     51          51   51     51            51     51
# 1948    68     68          68   68     68            68     68
# 1952    67     67          67   67     67            67     67
# 1956    72     72          72   72     72            72     72
# 1960    81     81          81   81     81            81     81
# 1964   103    103         103  103    103           103    103
# 1968   106    106         106  106    106           106    106
# 1972   105    105         105  105    105           105    105
# 1976   111    111         111  111    111           111    111
# 1980   115    115         115  115    115           115    115
# 1984   117    117         117  117    117           117    117
# ...

# %%
import pandas as pd
url = 'http://winterolympicsmedals.com/medals.csv'
data = pd.read_csv(url)
data['NOC'].value_counts()
# Out:
# NOR    280
# USA    216
# URS    194
# AUT    185
# GER    158
# FIN    151
# CAN    119
# SUI    118
# SWE    118
# GDR    110
# ITA    101
# FRA     83
# NED     78
# RUS     76
# FRG     41
# CHN     33
# JPN     32
# KOR     31
# TCH     25
# EUN     23
# GBR     21
# EUA     19
# CZE     10
# LIE      9
# POL      8
# CRO      7
# BUL      6
# EST      6
# AUS      6
# BLR      6
# HUN      6
# UKR      5
# BEL      5
# KAZ      5
# YUG      4
# SLO      4
# ESP      2
# PRK      2
# LUX      2
# LAT      1
# ROU      1
# DEN      1
# UZB      1
# NZL      1
# SVK      1
# Name: NOC, dtype: int64

# %%
import pandas as pd
url = 'http://winterolympicsmedals.com/medals.csv'
data = pd.read_csv(url)
data.groupby(['NOC','Medal']).count()
# Out:
#             Year  City  Sport  Discipline  Event  Event gender
# NOC Medal
# AUS Bronze     3     3      3           3      3             3
#     Gold       3     3      3           3      3             3
# AUT Bronze    70    70     70          70     70            70
#     Gold      51    51     51          51     51            51
#     Silver    64    64     64          64     64            64
# ...          ...   ...    ...         ...    ...           ...
# USA Gold      78    78     78          78     78            78
#     Silver    80    80     80          80     80            80
# UZB Gold       1     1      1           1      1             1
# YUG Bronze     1     1      1           1      1             1
#     Silver     3     3      3           3      3             3
#
# [112 rows x 6 columns]
