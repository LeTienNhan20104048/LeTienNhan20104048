# %% [markdown]
# <a href="https://colab.research.google.com/github/LeTienNhan20104048/LeTienNhan20104048/blob/main/Tuan_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from openpyxl import Workbook
Wb= Workbook()
sheet= Wb.active
sheet['A1']= 'Nguyen Van A'
sheet['B1']= '20104001'
sheet['A2']= 'Le Thi B'
sheet['B2']= '20104002'
Wb.save('test.xlsx')

# %%
import openpyxl
Wb= openpyxl.load_workbook('test.xlsx')
sheet= Wb.active
t1= sheet['A1']
t2= sheet['B1']
t3= sheet.cell(row=2, column=1)
t4= sheet.cell(row=2, column=2)
print(t1.value,t2.value)
print(t3.value,t4.value)
# Out:
# Nguyen Van A 20104001
# Le Thi B 20104002

# %%
import openpyxl
my_wb = openpyxl.Workbook()
my_sheet= my_wb.active
c1= my_sheet.cell(row=1, column=1)
c1.value = 'Dang Tri Dung'
c2 = my_sheet.cell(row=1, column=2)
c2.value= 'Trinh Duc Cuong'
c3 = my_sheet['A2']
c3.value= 'Ulsan'
c4 = my_sheet['B2']
c4.value = 'Genovoa'
my_wb.save('test2.xlsx')

# %%
import openpyxl
my_wb = openpyxl.Workbook()
my_sheet= my_wb.active
my_wb.create_sheet(index=1, title= 'CDT')
my_wb.save('test3.xlsx')

# %%
import openpyxl
my_path= 'test2.xlsx'
my_wb_obj= openpyxl.load_workbook(my_path)
my_sheet_obj=my_wb_obj.active
print(my_sheet_obj.max_row)
my_cell_obj = my_sheet_obj.cell(row=1,column=1)
print(my_cell_obj.value)
# Out:
# 2
# Dang Tri Dung

# %%
import openpyxl
path= 'test2.xlsx'
my_wb_obj = openpyxl.load_workbook(path)
sheet_obj = my_wb_obj.active
print(sheet_obj.max_column)
# Out:
# 2

# %%
Wb= openpyxl.load_workbook('test2.xlsx')
sheet= Wb.active
maxcl= sheet.max_column
for i in range(1, maxcl+1):
  cell= sheet.cell( row= 1, column= i)
  print(cell.value)
# Out:
# Dang Tri Dung
# Trinh Duc Cuong

# %%
Wb= openpyxl.load_workbook('test2.xlsx')
sheet= Wb.active
maxcl= sheet.max_column
for i in range(1, maxcl+1):
  cell= sheet.cell( row= 2, column= i)
  print(cell.value, end =" ")
# Out:
# Ulsan Genovoa

# %%
import matplotlib.pyplot as plt
import numpy as np
x= np.arange(6)
y= x+1
plt.plot(x,y,'o--')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x= np.arange(6)
y= x+1
plt.plot(x,y,'o--')
plt.plot(x,-y,'o--')
plt.title('y=x va y=-x')
plt.xlabel('x')
plt.ylabel('y')
plt.axis('off')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x= np.arange(6)
y= x+1
plt.plot(x,y,'o--')
plt.plot(x,-y,'o--')
plt.title('y=x va y=-x')
plt.grid('on')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
N=16
x=np.linspace(0,15,16)
y=x
plt.plot(x,y,'--o')
plt.axis('off')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
N=16
x=np.linspace(0,15,16)
y=np.logspace(0.1,2,16)
plt.plot(x,y,'--o')
plt.axis('off')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=[4,5,3,1,6,7]
plt.plot(x)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.arange(25)
plt.plot(x)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.arange(25)
plt.plot(x,x**3+1)
plt.show()

# %%
x=np.arange(7)
plt.plot(x,-x**2)
plt.plot(x,-x**3)
plt.plot(x,-2*x)
plt.plot(x,-2**x)
plt.show()

# %%
x=np.arange(7)
plt.plot(x,-x**2,'-')
plt.plot(x,-x**3,'--')
plt.plot(x,-2*x,'-.')
plt.plot(x,-2**x,':')
plt.show()

# %%
x=np.arange(7)
plt.plot(x,-x**2,x,-x**3,x,-2*x,x,-2**x)
plt.grid(True)
plt.savefig('test.png')
plt.show()

# %%
x=np.arange(3)
plt.subplots_adjust(wspace=0.3,hspace=0.3)
plt.subplot(2,2,1)
plt.plot(x,-x**2,color='g')
plt.subplot(2,2,2)
plt.plot(x,-x**3,color='r')
plt.subplot(2,2,3)
plt.plot(x,-2*x,color='b')
plt.subplot(2,2,4)
plt.plot(x,-2**x,'o')
plt.show()

# %%
plt.axis([0,150,0,10])
plt.scatter(60,5,s=1000, color='b',alpha=1)
plt.scatter(80,5,s=1000, color='b', alpha=.5)
plt.scatter(100,5,s=1000, color='b', alpha=.1)
plt.show()

# %%
plt.plot([3,5],[7,15], linewidth=5, color='r')
plt.text(4,8,'text')
plt.show()

# %%
plt.axis([0,20, 0,20])
plt.arrow(12,0,0,6, head_length=4, head_width=2, color='g')
plt.show()

# %%
x=np.arange(4)
y=np.random.rand(4)
plt.bar(x,y)
plt.show()

# %%
x=np.arange(4)
y=np.random.rand(4)
plt.barh(x,y)
plt.show()

# %%
y=np.random.rand(3,4)
plt.bar(x+0,y[0],color='b', width=0.25)
plt.bar(x+0.25,y[1], color='y', width=0.25)
plt.bar(x+0.5,y[2], color='r', width=0.25)
plt.show()

# %%
N=1000
x=np.random.rand(N)
y=np.random.rand(N)
colors=np.random.rand(N)
size=20
plt.scatter(x,y,s=size,c=colors,alpha=1)
plt.show()
